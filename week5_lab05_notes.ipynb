# %% [markdown]
# # Lab 05 - Class Notes
#
#  * ENGR114 Winter 2019
#  * Lab 05: Web API's
#  * Date: 2019-02-07

# %%
from user_input import user_input
from call_API import call_API
from clean_data import clean_data
from plot_data import plot_data

n_points, w_type = user_input()
m_data = call_api(n_points, w_type)
c_data = clean_data(m_data)
plot_data(c_data,w_type)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ad1be59b8e34> in <module>()
# ----> 1 from user_input import user_input
#       2 from call_API import call_API
#       3 from clean_data import clean_data
#       4 from plot_data import plot_data
#       5
#
# ModuleNotFoundError: No module named 'user_input'

# %%
import numpy as np
#need to call %matplotlib inline to get the plot to show in a Jupyter notebook
# %matplotlib inline   

from plot_data import plot_data
random_data = np.random.randint(low = 1, high=10, size=20)
w_type = 'temperature'
plot_data(random_data, w_type)
